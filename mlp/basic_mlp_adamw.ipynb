# %% [markdown]
# # Basic Multilayer Perceptron - AdamW Optimizer

# %% [markdown]
# This notebook has the same MLP as the basic MLP notebook, the only difference is that I use AdamW as my optimizer

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# From local helper files
from mlp.helpers.helper_datasets import get_dataloaders_mnist
from mlp.helpers.helper_train import train_model
from mlp.helpers.helper_plotting import plot_training_loss, plot_accuracy

# %% [markdown]
# # Settings and Dataset

# %%
##########################
### SETTINGS
##########################

RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_HIDDEN_1 = 75
NUM_HIDDEN_2 = 45
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Get Data
train_loader, valid_loader, test_loader = get_dataloaders_mnist(
    batch_size=BATCH_SIZE,
    validation_fraction=0.1)

# %% [markdown]
# # Model
# We will create a basic multilayer perceptron neural network using pytorch.
#
# The network will have 784 input features corresponding to the 28*28 MNIST images
#
# The network will predict that the image is one of ten classes corresponding to numbers from 0 to 9
#
# The network will have 2 hidden layers, see NUM_HIDDEN_1 and NUM_HIDDEN_2 for their sizes

# %%
class MLP(torch.nn.Module):
    def __init__(self, num_features, num_classes, drop_proba, num_hidden_1, num_hidden_2):
        super().__init__()
        self.network = torch.nn.Sequential(
            # Layer 1
            torch.nn.Flatten(),
            torch.nn.Linear(num_features, num_hidden_1),
            torch.nn.ReLU(),
            # Layer 2
            torch.nn.Linear(num_hidden_1, num_hidden_2),
            torch.nn.ReLU(),
            # Output layer
            torch.nn.Linear(num_hidden_2, num_classes)
        )
    
    def forward(self, x):
        return self.network(x)

# %%
torch.manual_seed(RANDOM_SEED)

model = MLP(num_features=28*28,
            num_classes=10,
            num_hidden_1=NUM_HIDDEN_1,
            num_hidden_2=NUM_HIDDEN_2,
            drop_proba=0.5)


optimizer = torch.optim.AdamW(model.parameters(), lr=0.005)

# %%
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(model=model, 
                                                                  num_epochs=NUM_EPOCHS, 
                                                                  train_loader=train_loader,
                                                                  valid_loader=valid_loader, 
                                                                  test_loader=test_loader, 
                                                                  optimizer=optimizer,
                                                                  device=DEVICE)


plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=20)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([80, 100])
plt.show()
# Out:
# Epoch: 001/050 | Batch 0000/0210 | Loss: 2.3093
# Epoch: 001/050 | Batch 0050/0210 | Loss: 0.4144
# Epoch: 001/050 | Batch 0100/0210 | Loss: 0.2171
# Epoch: 001/050 | Batch 0150/0210 | Loss: 0.2503
# Epoch: 001/050 | Batch 0200/0210 | Loss: 0.1598
# Epoch: 001/050 | Train: 94.24% | Validation: 95.08%
# Time elapsed: 0.06 min
# Epoch: 002/050 | Batch 0000/0210 | Loss: 0.1555
# Epoch: 002/050 | Batch 0050/0210 | Loss: 0.1760
# Epoch: 002/050 | Batch 0100/0210 | Loss: 0.1219
# Epoch: 002/050 | Batch 0150/0210 | Loss: 0.1629
# Epoch: 002/050 | Batch 0200/0210 | Loss: 0.1439
# Epoch: 002/050 | Train: 96.78% | Validation: 96.60%
# Time elapsed: 0.11 min
# Epoch: 003/050 | Batch 0000/0210 | Loss: 0.0791
# Epoch: 003/050 | Batch 0050/0210 | Loss: 0.0807
# Epoch: 003/050 | Batch 0100/0210 | Loss: 0.0511
# Epoch: 003/050 | Batch 0150/0210 | Loss: 0.0849
# Epoch: 003/050 | Batch 0200/0210 | Loss: 0.1346
# Epoch: 003/050 | Train: 97.36% | Validation: 96.75%
# Time elapsed: 0.16 min
# Epoch: 004/050 | Batch 0000/0210 | Loss: 0.0595
# Epoch: 004/050 | Batch 0050/0210 | Loss: 0.1040
# Epoch: 004/050 | Batch 0100/0210 | Loss: 0.0973
# Epoch: 004/050 | Batch 0150/0210 | Loss: 0.1496
# Epoch: 004/050 | Batch 0200/0210 | Loss: 0.0881
# Epoch: 004/050 | Train: 98.30% | Validation: 97.23%
# Time elapsed: 0.22 min
# Epoch: 005/050 | Batch 0000/0210 | Loss: 0.0660
# Epoch: 005/050 | Batch 0050/0210 | Loss: 0.0590
# Epoch: 005/050 | Batch 0100/0210 | Loss: 0.0545
# Epoch: 005/050 | Batch 0150/0210 | Loss: 0.0473
# Epoch: 005/050 | Batch 0200/0210 | Loss: 0.0773
# Epoch: 005/050 | Train: 98.02% | Validation: 96.62%
# Time elapsed: 0.28 min
# Epoch: 006/050 | Batch 0000/0210 | Loss: 0.0547
# Epoch: 006/050 | Batch 0050/0210 | Loss: 0.0685
# Epoch: 006/050 | Batch 0100/0210 | Loss: 0.0528
# Epoch: 006/050 | Batch 0150/0210 | Loss: 0.0107
# Epoch: 006/050 | Batch 0200/0210 | Loss: 0.0842
# Epoch: 006/050 | Train: 98.87% | Validation: 97.32%
# Time elapsed: 0.33 min
# Epoch: 007/050 | Batch 0000/0210 | Loss: 0.0341
# Epoch: 007/050 | Batch 0050/0210 | Loss: 0.0600
# Epoch: 007/050 | Batch 0100/0210 | Loss: 0.0419
# Epoch: 007/050 | Batch 0150/0210 | Loss: 0.0394
# Epoch: 007/050 | Batch 0200/0210 | Loss: 0.0359
# Epoch: 007/050 | Train: 98.55% | Validation: 96.85%
# Time elapsed: 0.39 min
# Epoch: 008/050 | Batch 0000/0210 | Loss: 0.0895
# Epoch: 008/050 | Batch 0050/0210 | Loss: 0.0482
# Epoch: 008/050 | Batch 0100/0210 | Loss: 0.0537
# Epoch: 008/050 | Batch 0150/0210 | Loss: 0.0469
# Epoch: 008/050 | Batch 0200/0210 | Loss: 0.1665
# Epoch: 008/050 | Train: 98.69% | Validation: 97.40%
# Time elapsed: 0.45 min
# Epoch: 009/050 | Batch 0000/0210 | Loss: 0.0307
# Epoch: 009/050 | Batch 0050/0210 | Loss: 0.0252
# Epoch: 009/050 | Batch 0100/0210 | Loss: 0.0595
# Epoch: 009/050 | Batch 0150/0210 | Loss: 0.0400
# Epoch: 009/050 | Batch 0200/0210 | Loss: 0.0266
# Epoch: 009/050 | Train: 99.21% | Validation: 97.52%
# Time elapsed: 0.51 min
# Epoch: 010/050 | Batch 0000/0210 | Loss: 0.0365
# Epoch: 010/050 | Batch 0050/0210 | Loss: 0.0106
# Epoch: 010/050 | Batch 0100/0210 | Loss: 0.0135
# Epoch: 010/050 | Batch 0150/0210 | Loss: 0.0252
# Epoch: 010/050 | Batch 0200/0210 | Loss: 0.0274
# Epoch: 010/050 | Train: 98.80% | Validation: 97.15%
# Time elapsed: 0.57 min
# Epoch: 011/050 | Batch 0000/0210 | Loss: 0.0527
# Epoch: 011/050 | Batch 0050/0210 | Loss: 0.0353
# Epoch: 011/050 | Batch 0100/0210 | Loss: 0.0174
# Epoch: 011/050 | Batch 0150/0210 | Loss: 0.0350
# Epoch: 011/050 | Batch 0200/0210 | Loss: 0.0413
# Epoch: 011/050 | Train: 99.15% | Validation: 97.33%
# Time elapsed: 0.63 min
# Epoch: 012/050 | Batch 0000/0210 | Loss: 0.0243
# Epoch: 012/050 | Batch 0050/0210 | Loss: 0.0233
# Epoch: 012/050 | Batch 0100/0210 | Loss: 0.0133
# Epoch: 012/050 | Batch 0150/0210 | Loss: 0.0478
# Epoch: 012/050 | Batch 0200/0210 | Loss: 0.0100
# Epoch: 012/050 | Train: 99.27% | Validation: 97.53%
# Time elapsed: 0.69 min
# Epoch: 013/050 | Batch 0000/0210 | Loss: 0.0045
# Epoch: 013/050 | Batch 0050/0210 | Loss: 0.0311
# Epoch: 013/050 | Batch 0100/0210 | Loss: 0.0230
# Epoch: 013/050 | Batch 0150/0210 | Loss: 0.0283
# Epoch: 013/050 | Batch 0200/0210 | Loss: 0.0055
# Epoch: 013/050 | Train: 99.25% | Validation: 97.48%
# Time elapsed: 0.74 min
# Epoch: 014/050 | Batch 0000/0210 | Loss: 0.0235
# Epoch: 014/050 | Batch 0050/0210 | Loss: 0.0349
# Epoch: 014/050 | Batch 0100/0210 | Loss: 0.0115
# Epoch: 014/050 | Batch 0150/0210 | Loss: 0.0357
# Epoch: 014/050 | Batch 0200/0210 | Loss: 0.0166
# Epoch: 014/050 | Train: 99.48% | Validation: 97.37%
# Time elapsed: 0.80 min
# Epoch: 015/050 | Batch 0000/0210 | Loss: 0.0200
# Epoch: 015/050 | Batch 0050/0210 | Loss: 0.0059
# Epoch: 015/050 | Batch 0100/0210 | Loss: 0.0117
# Epoch: 015/050 | Batch 0150/0210 | Loss: 0.0185
# Epoch: 015/050 | Batch 0200/0210 | Loss: 0.0127
# Epoch: 015/050 | Train: 99.36% | Validation: 97.60%
# Time elapsed: 0.86 min
# Epoch: 016/050 | Batch 0000/0210 | Loss: 0.0078
# Epoch: 016/050 | Batch 0050/0210 | Loss: 0.0104
# Epoch: 016/050 | Batch 0100/0210 | Loss: 0.0120
# Epoch: 016/050 | Batch 0150/0210 | Loss: 0.0518
# Epoch: 016/050 | Batch 0200/0210 | Loss: 0.0261
# Epoch: 016/050 | Train: 99.31% | Validation: 97.42%
# Time elapsed: 0.92 min
# Epoch: 017/050 | Batch 0000/0210 | Loss: 0.0185
# Epoch: 017/050 | Batch 0050/0210 | Loss: 0.0352
# Epoch: 017/050 | Batch 0100/0210 | Loss: 0.0313
# Epoch: 017/050 | Batch 0150/0210 | Loss: 0.0061
# Epoch: 017/050 | Batch 0200/0210 | Loss: 0.0220
# Epoch: 017/050 | Train: 99.50% | Validation: 97.58%
# Time elapsed: 0.97 min
# Epoch: 018/050 | Batch 0000/0210 | Loss: 0.0186
# Epoch: 018/050 | Batch 0050/0210 | Loss: 0.0026
# Epoch: 018/050 | Batch 0100/0210 | Loss: 0.0081
# Epoch: 018/050 | Batch 0150/0210 | Loss: 0.0366
# Epoch: 018/050 | Batch 0200/0210 | Loss: 0.0224
# Epoch: 018/050 | Train: 99.68% | Validation: 97.45%
# Time elapsed: 1.03 min
# Epoch: 019/050 | Batch 0000/0210 | Loss: 0.0169
# Epoch: 019/050 | Batch 0050/0210 | Loss: 0.0286
# Epoch: 019/050 | Batch 0100/0210 | Loss: 0.0090
# Epoch: 019/050 | Batch 0150/0210 | Loss: 0.0034
# Epoch: 019/050 | Batch 0200/0210 | Loss: 0.0279
# Epoch: 019/050 | Train: 99.18% | Validation: 97.23%
# Time elapsed: 1.09 min
# Epoch: 020/050 | Batch 0000/0210 | Loss: 0.0369
# Epoch: 020/050 | Batch 0050/0210 | Loss: 0.0057
# Epoch: 020/050 | Batch 0100/0210 | Loss: 0.0072
# Epoch: 020/050 | Batch 0150/0210 | Loss: 0.0326
# Epoch: 020/050 | Batch 0200/0210 | Loss: 0.0125
# Epoch: 020/050 | Train: 99.59% | Validation: 97.73%
# Time elapsed: 1.15 min
# Epoch: 021/050 | Batch 0000/0210 | Loss: 0.0073
# Epoch: 021/050 | Batch 0050/0210 | Loss: 0.0005
# Epoch: 021/050 | Batch 0100/0210 | Loss: 0.0070
# Epoch: 021/050 | Batch 0150/0210 | Loss: 0.0256
# Epoch: 021/050 | Batch 0200/0210 | Loss: 0.0516
# Epoch: 021/050 | Train: 99.51% | Validation: 97.62%
# Time elapsed: 1.21 min
# Epoch: 022/050 | Batch 0000/0210 | Loss: 0.0104
# Epoch: 022/050 | Batch 0050/0210 | Loss: 0.0195
# Epoch: 022/050 | Batch 0100/0210 | Loss: 0.0189
# Epoch: 022/050 | Batch 0150/0210 | Loss: 0.0357
# Epoch: 022/050 | Batch 0200/0210 | Loss: 0.0132
# Epoch: 022/050 | Train: 99.59% | Validation: 97.88%
# Time elapsed: 1.27 min
# Epoch: 023/050 | Batch 0000/0210 | Loss: 0.0007
# Epoch: 023/050 | Batch 0050/0210 | Loss: 0.0065
# Epoch: 023/050 | Batch 0100/0210 | Loss: 0.0308
# Epoch: 023/050 | Batch 0150/0210 | Loss: 0.0219
# Epoch: 023/050 | Batch 0200/0210 | Loss: 0.0646
# Epoch: 023/050 | Train: 99.03% | Validation: 97.28%
# Time elapsed: 1.33 min
# Epoch: 024/050 | Batch 0000/0210 | Loss: 0.0065
# Epoch: 024/050 | Batch 0050/0210 | Loss: 0.0169
# Epoch: 024/050 | Batch 0100/0210 | Loss: 0.0196
# Epoch: 024/050 | Batch 0150/0210 | Loss: 0.0279
# Epoch: 024/050 | Batch 0200/0210 | Loss: 0.0666
# Epoch: 024/050 | Train: 99.63% | Validation: 97.70%
# Time elapsed: 1.39 min
# Epoch: 025/050 | Batch 0000/0210 | Loss: 0.0263
# Epoch: 025/050 | Batch 0050/0210 | Loss: 0.0016
# Epoch: 025/050 | Batch 0100/0210 | Loss: 0.0189
# Epoch: 025/050 | Batch 0150/0210 | Loss: 0.0185
# Epoch: 025/050 | Batch 0200/0210 | Loss: 0.0347
# Epoch: 025/050 | Train: 99.27% | Validation: 97.57%
# Time elapsed: 1.44 min
# Epoch: 026/050 | Batch 0000/0210 | Loss: 0.0332
# Epoch: 026/050 | Batch 0050/0210 | Loss: 0.0122
# Epoch: 026/050 | Batch 0100/0210 | Loss: 0.0314
# Epoch: 026/050 | Batch 0150/0210 | Loss: 0.0178
# Epoch: 026/050 | Batch 0200/0210 | Loss: 0.0074
# Epoch: 026/050 | Train: 99.56% | Validation: 97.37%
# Time elapsed: 1.50 min
# Epoch: 027/050 | Batch 0000/0210 | Loss: 0.0214
# Epoch: 027/050 | Batch 0050/0210 | Loss: 0.0030
# Epoch: 027/050 | Batch 0100/0210 | Loss: 0.0283
# Epoch: 027/050 | Batch 0150/0210 | Loss: 0.0030
# Epoch: 027/050 | Batch 0200/0210 | Loss: 0.0015
# Epoch: 027/050 | Train: 99.68% | Validation: 97.68%
# Time elapsed: 1.56 min
# Epoch: 028/050 | Batch 0000/0210 | Loss: 0.0190
# Epoch: 028/050 | Batch 0050/0210 | Loss: 0.0114
# Epoch: 028/050 | Batch 0100/0210 | Loss: 0.0246
# Epoch: 028/050 | Batch 0150/0210 | Loss: 0.0207
# Epoch: 028/050 | Batch 0200/0210 | Loss: 0.0313
# Epoch: 028/050 | Train: 99.77% | Validation: 97.82%
# Time elapsed: 1.62 min
# Epoch: 029/050 | Batch 0000/0210 | Loss: 0.0097
# Epoch: 029/050 | Batch 0050/0210 | Loss: 0.0319
# Epoch: 029/050 | Batch 0100/0210 | Loss: 0.0143
# Epoch: 029/050 | Batch 0150/0210 | Loss: 0.0033
# Epoch: 029/050 | Batch 0200/0210 | Loss: 0.0050
# Epoch: 029/050 | Train: 99.49% | Validation: 97.67%
# Time elapsed: 1.68 min
# Epoch: 030/050 | Batch 0000/0210 | Loss: 0.0031
# Epoch: 030/050 | Batch 0050/0210 | Loss: 0.0161
# Epoch: 030/050 | Batch 0100/0210 | Loss: 0.0059
# Epoch: 030/050 | Batch 0150/0210 | Loss: 0.0035
# Epoch: 030/050 | Batch 0200/0210 | Loss: 0.0055
# Epoch: 030/050 | Train: 99.56% | Validation: 97.53%
# Time elapsed: 1.74 min
# Epoch: 031/050 | Batch 0000/0210 | Loss: 0.0271
# Epoch: 031/050 | Batch 0050/0210 | Loss: 0.0010
# Epoch: 031/050 | Batch 0100/0210 | Loss: 0.0006
# Epoch: 031/050 | Batch 0150/0210 | Loss: 0.0048
# Epoch: 031/050 | Batch 0200/0210 | Loss: 0.0332
# Epoch: 031/050 | Train: 99.68% | Validation: 97.53%
# Time elapsed: 1.80 min
# Epoch: 032/050 | Batch 0000/0210 | Loss: 0.0084
# Epoch: 032/050 | Batch 0050/0210 | Loss: 0.0071
# Epoch: 032/050 | Batch 0100/0210 | Loss: 0.0292
# Epoch: 032/050 | Batch 0150/0210 | Loss: 0.0143
# Epoch: 032/050 | Batch 0200/0210 | Loss: 0.0056
# Epoch: 032/050 | Train: 99.63% | Validation: 97.92%
# Time elapsed: 1.86 min
# Epoch: 033/050 | Batch 0000/0210 | Loss: 0.0304
# Epoch: 033/050 | Batch 0050/0210 | Loss: 0.0492
# Epoch: 033/050 | Batch 0100/0210 | Loss: 0.0117
# Epoch: 033/050 | Batch 0150/0210 | Loss: 0.0132
# Epoch: 033/050 | Batch 0200/0210 | Loss: 0.0071
# Epoch: 033/050 | Train: 99.50% | Validation: 97.85%
# Time elapsed: 1.92 min
# Epoch: 034/050 | Batch 0000/0210 | Loss: 0.0130
# Epoch: 034/050 | Batch 0050/0210 | Loss: 0.0179
# Epoch: 034/050 | Batch 0100/0210 | Loss: 0.0582
# Epoch: 034/050 | Batch 0150/0210 | Loss: 0.0318
# Epoch: 034/050 | Batch 0200/0210 | Loss: 0.0076
# Epoch: 034/050 | Train: 99.53% | Validation: 97.28%
# Time elapsed: 1.98 min
# Epoch: 035/050 | Batch 0000/0210 | Loss: 0.0219
# Epoch: 035/050 | Batch 0050/0210 | Loss: 0.0549
# Epoch: 035/050 | Batch 0100/0210 | Loss: 0.0051
# Epoch: 035/050 | Batch 0150/0210 | Loss: 0.0016
# Epoch: 035/050 | Batch 0200/0210 | Loss: 0.0023
# Epoch: 035/050 | Train: 99.81% | Validation: 97.97%
# Time elapsed: 2.03 min
# Epoch: 036/050 | Batch 0000/0210 | Loss: 0.0031
# Epoch: 036/050 | Batch 0050/0210 | Loss: 0.0033
# Epoch: 036/050 | Batch 0100/0210 | Loss: 0.0061
# Epoch: 036/050 | Batch 0150/0210 | Loss: 0.0172
# Epoch: 036/050 | Batch 0200/0210 | Loss: 0.0349
# Epoch: 036/050 | Train: 99.74% | Validation: 97.72%
# Time elapsed: 2.09 min
# Epoch: 037/050 | Batch 0000/0210 | Loss: 0.0157
# Epoch: 037/050 | Batch 0050/0210 | Loss: 0.0026
# Epoch: 037/050 | Batch 0100/0210 | Loss: 0.0049
# Epoch: 037/050 | Batch 0150/0210 | Loss: 0.0284
# Epoch: 037/050 | Batch 0200/0210 | Loss: 0.0091
# Epoch: 037/050 | Train: 99.54% | Validation: 97.43%
# Time elapsed: 2.15 min
# Epoch: 038/050 | Batch 0000/0210 | Loss: 0.0045
# Epoch: 038/050 | Batch 0050/0210 | Loss: 0.0038
# Epoch: 038/050 | Batch 0100/0210 | Loss: 0.0339
# Epoch: 038/050 | Batch 0150/0210 | Loss: 0.0991
# Epoch: 038/050 | Batch 0200/0210 | Loss: 0.0968
# Epoch: 038/050 | Train: 99.18% | Validation: 97.37%
# Time elapsed: 2.21 min
# Epoch: 039/050 | Batch 0000/0210 | Loss: 0.0273
# Epoch: 039/050 | Batch 0050/0210 | Loss: 0.0032
# Epoch: 039/050 | Batch 0100/0210 | Loss: 0.0024
# Epoch: 039/050 | Batch 0150/0210 | Loss: 0.0106
# Epoch: 039/050 | Batch 0200/0210 | Loss: 0.0064
# Epoch: 039/050 | Train: 99.71% | Validation: 97.77%
# Time elapsed: 2.27 min
# Epoch: 040/050 | Batch 0000/0210 | Loss: 0.0024
# Epoch: 040/050 | Batch 0050/0210 | Loss: 0.0107
# Epoch: 040/050 | Batch 0100/0210 | Loss: 0.0069
# Epoch: 040/050 | Batch 0150/0210 | Loss: 0.0272
# Epoch: 040/050 | Batch 0200/0210 | Loss: 0.0351
# Epoch: 040/050 | Train: 99.87% | Validation: 98.08%
# Time elapsed: 2.33 min
# Epoch: 041/050 | Batch 0000/0210 | Loss: 0.0032
# Epoch: 041/050 | Batch 0050/0210 | Loss: 0.0041
# Epoch: 041/050 | Batch 0100/0210 | Loss: 0.0042
# Epoch: 041/050 | Batch 0150/0210 | Loss: 0.0014
# Epoch: 041/050 | Batch 0200/0210 | Loss: 0.0497
# Epoch: 041/050 | Train: 99.73% | Validation: 97.85%
# Time elapsed: 2.39 min
# Epoch: 042/050 | Batch 0000/0210 | Loss: 0.0042
# Epoch: 042/050 | Batch 0050/0210 | Loss: 0.0019
# Epoch: 042/050 | Batch 0100/0210 | Loss: 0.0032
# Epoch: 042/050 | Batch 0150/0210 | Loss: 0.0157
# Epoch: 042/050 | Batch 0200/0210 | Loss: 0.0142
# Epoch: 042/050 | Train: 99.43% | Validation: 97.68%
# Time elapsed: 2.45 min
# Epoch: 043/050 | Batch 0000/0210 | Loss: 0.0142
# Epoch: 043/050 | Batch 0050/0210 | Loss: 0.0039
# Epoch: 043/050 | Batch 0100/0210 | Loss: 0.0100
# Epoch: 043/050 | Batch 0150/0210 | Loss: 0.0074
# Epoch: 043/050 | Batch 0200/0210 | Loss: 0.0077
# Epoch: 043/050 | Train: 99.77% | Validation: 97.93%
# Time elapsed: 2.51 min
# Epoch: 044/050 | Batch 0000/0210 | Loss: 0.0004
# Epoch: 044/050 | Batch 0050/0210 | Loss: 0.0005
# Epoch: 044/050 | Batch 0100/0210 | Loss: 0.0180
# Epoch: 044/050 | Batch 0150/0210 | Loss: 0.0023
# Epoch: 044/050 | Batch 0200/0210 | Loss: 0.0018
# Epoch: 044/050 | Train: 99.75% | Validation: 97.65%
# Time elapsed: 2.57 min
# Epoch: 045/050 | Batch 0000/0210 | Loss: 0.0280
# Epoch: 045/050 | Batch 0050/0210 | Loss: 0.0096
# Epoch: 045/050 | Batch 0100/0210 | Loss: 0.0010
# Epoch: 045/050 | Batch 0150/0210 | Loss: 0.0343
# Epoch: 045/050 | Batch 0200/0210 | Loss: 0.0022
# Epoch: 045/050 | Train: 99.72% | Validation: 97.97%
# Time elapsed: 2.63 min
# Epoch: 046/050 | Batch 0000/0210 | Loss: 0.0109
# Epoch: 046/050 | Batch 0050/0210 | Loss: 0.0062
# Epoch: 046/050 | Batch 0100/0210 | Loss: 0.0012
# Epoch: 046/050 | Batch 0150/0210 | Loss: 0.0146
# Epoch: 046/050 | Batch 0200/0210 | Loss: 0.0015
# Epoch: 046/050 | Train: 99.75% | Validation: 97.83%
# Time elapsed: 2.69 min
# Epoch: 047/050 | Batch 0000/0210 | Loss: 0.0011
# Epoch: 047/050 | Batch 0050/0210 | Loss: 0.0015
# Epoch: 047/050 | Batch 0100/0210 | Loss: 0.0054
# Epoch: 047/050 | Batch 0150/0210 | Loss: 0.0066
# Epoch: 047/050 | Batch 0200/0210 | Loss: 0.0092
# Epoch: 047/050 | Train: 99.69% | Validation: 98.02%
# Time elapsed: 2.75 min
# Epoch: 048/050 | Batch 0000/0210 | Loss: 0.0167
# Epoch: 048/050 | Batch 0050/0210 | Loss: 0.0011
# Epoch: 048/050 | Batch 0100/0210 | Loss: 0.0013
# Epoch: 048/050 | Batch 0150/0210 | Loss: 0.0132
# Epoch: 048/050 | Batch 0200/0210 | Loss: 0.0147
# Epoch: 048/050 | Train: 99.79% | Validation: 97.85%
# Time elapsed: 2.81 min
# Epoch: 049/050 | Batch 0000/0210 | Loss: 0.0037
# Epoch: 049/050 | Batch 0050/0210 | Loss: 0.0095
# Epoch: 049/050 | Batch 0100/0210 | Loss: 0.0364
# Epoch: 049/050 | Batch 0150/0210 | Loss: 0.0048
# Epoch: 049/050 | Batch 0200/0210 | Loss: 0.0021
# Epoch: 049/050 | Train: 99.72% | Validation: 97.62%
# Time elapsed: 2.87 min
# Epoch: 050/050 | Batch 0000/0210 | Loss: 0.0326
# Epoch: 050/050 | Batch 0050/0210 | Loss: 0.0146
# Epoch: 050/050 | Batch 0100/0210 | Loss: 0.0006
# Epoch: 050/050 | Batch 0150/0210 | Loss: 0.0037
# Epoch: 050/050 | Batch 0200/0210 | Loss: 0.0054
# Epoch: 050/050 | Train: 99.70% | Validation: 97.75%
# Time elapsed: 2.92 min
# Total Training Time: 2.92 min
# Test accuracy 97.37%
