# %% [markdown]
# # Basic Multilayer Perceptron - With Leaky ReLU

# %% [markdown]
# This notebook has the same MLP as the basic MLP notebook, the only difference is that I use Leaky ReLU as my activation function.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# From local helper files
from mlp.helpers.helper_datasets import get_dataloaders_mnist
from mlp.helpers.helper_train import train_model
from mlp.helpers.helper_plotting import plot_training_loss, plot_accuracy

# %% [markdown]
# # Settings and Dataset

# %%
##########################
### SETTINGS
##########################

RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_HIDDEN_1 = 75
NUM_HIDDEN_2 = 45
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Get Data
train_loader, valid_loader, test_loader = get_dataloaders_mnist(
    batch_size=BATCH_SIZE,
    validation_fraction=0.1)

# %% [markdown]
# # Model
# We will create a basic multilayer perceptron neural network using pytorch.
#
# The network will have 784 input features corresponding to the 28*28 MNIST images
#
# The network will predict that the image is one of ten classes corresponding to numbers from 0 to 9
#
# The network will have 2 hidden layers, see NUM_HIDDEN_1 and NUM_HIDDEN_2 for their sizes

# %%
class MLP(torch.nn.Module):
    def __init__(self, num_features, num_classes, drop_proba, num_hidden_1, num_hidden_2):
        super().__init__()
        self.network = torch.nn.Sequential(
            # Layer 1
            torch.nn.Flatten(),
            torch.nn.Linear(num_features, num_hidden_1),
            torch.nn.LeakyReLU(),
            # Layer 2
            torch.nn.Linear(num_hidden_1, num_hidden_2),
            torch.nn.LeakyReLU(),
            # Output layer
            torch.nn.Linear(num_hidden_2, num_classes)
        )
    
    def forward(self, x):
        return self.network(x)

# %%
torch.manual_seed(RANDOM_SEED)

model = MLP(num_features=28*28,
            num_classes=10,
            num_hidden_1=NUM_HIDDEN_1,
            num_hidden_2=NUM_HIDDEN_2,
            drop_proba=0.5)


optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(model=model, 
                                                                  num_epochs=NUM_EPOCHS, 
                                                                  train_loader=train_loader,
                                                                  valid_loader=valid_loader, 
                                                                  test_loader=test_loader, 
                                                                  optimizer=optimizer,
                                                                  device=DEVICE)


plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=20)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([80, 100])
plt.show()
# Out:
# Epoch: 001/050 | Batch 0000/0210 | Loss: 2.3093
# Epoch: 001/050 | Batch 0050/0210 | Loss: 1.8408
# Epoch: 001/050 | Batch 0100/0210 | Loss: 0.7582
# Epoch: 001/050 | Batch 0150/0210 | Loss: 0.6517
# Epoch: 001/050 | Batch 0200/0210 | Loss: 0.5030
# Epoch: 001/050 | Train: 86.57% | Validation: 89.12%
# Time elapsed: 0.05 min
# Epoch: 002/050 | Batch 0000/0210 | Loss: 0.4678
# Epoch: 002/050 | Batch 0050/0210 | Loss: 0.4330
# Epoch: 002/050 | Batch 0100/0210 | Loss: 0.3326
# Epoch: 002/050 | Batch 0150/0210 | Loss: 0.3329
# Epoch: 002/050 | Batch 0200/0210 | Loss: 0.3601
# Epoch: 002/050 | Train: 90.23% | Validation: 92.17%
# Time elapsed: 0.11 min
# Epoch: 003/050 | Batch 0000/0210 | Loss: 0.2565
# Epoch: 003/050 | Batch 0050/0210 | Loss: 0.2748
# Epoch: 003/050 | Batch 0100/0210 | Loss: 0.2671
# Epoch: 003/050 | Batch 0150/0210 | Loss: 0.2205
# Epoch: 003/050 | Batch 0200/0210 | Loss: 0.3530
# Epoch: 003/050 | Train: 91.07% | Validation: 92.57%
# Time elapsed: 0.17 min
# Epoch: 004/050 | Batch 0000/0210 | Loss: 0.3443
# Epoch: 004/050 | Batch 0050/0210 | Loss: 0.2966
# Epoch: 004/050 | Batch 0100/0210 | Loss: 0.2467
# Epoch: 004/050 | Batch 0150/0210 | Loss: 0.4020
# Epoch: 004/050 | Batch 0200/0210 | Loss: 0.2625
# Epoch: 004/050 | Train: 92.87% | Validation: 93.93%
# Time elapsed: 0.22 min
# Epoch: 005/050 | Batch 0000/0210 | Loss: 0.3648
# Epoch: 005/050 | Batch 0050/0210 | Loss: 0.2362
# Epoch: 005/050 | Batch 0100/0210 | Loss: 0.1951
# Epoch: 005/050 | Batch 0150/0210 | Loss: 0.1814
# Epoch: 005/050 | Batch 0200/0210 | Loss: 0.1763
# Epoch: 005/050 | Train: 93.71% | Validation: 94.53%
# Time elapsed: 0.28 min
# Epoch: 006/050 | Batch 0000/0210 | Loss: 0.2479
# Epoch: 006/050 | Batch 0050/0210 | Loss: 0.2001
# Epoch: 006/050 | Batch 0100/0210 | Loss: 0.2035
# Epoch: 006/050 | Batch 0150/0210 | Loss: 0.1531
# Epoch: 006/050 | Batch 0200/0210 | Loss: 0.2706
# Epoch: 006/050 | Train: 94.42% | Validation: 95.35%
# Time elapsed: 0.33 min
# Epoch: 007/050 | Batch 0000/0210 | Loss: 0.2273
# Epoch: 007/050 | Batch 0050/0210 | Loss: 0.1779
# Epoch: 007/050 | Batch 0100/0210 | Loss: 0.1885
# Epoch: 007/050 | Batch 0150/0210 | Loss: 0.2745
# Epoch: 007/050 | Batch 0200/0210 | Loss: 0.0882
# Epoch: 007/050 | Train: 94.85% | Validation: 95.73%
# Time elapsed: 0.39 min
# Epoch: 008/050 | Batch 0000/0210 | Loss: 0.2674
# Epoch: 008/050 | Batch 0050/0210 | Loss: 0.2508
# Epoch: 008/050 | Batch 0100/0210 | Loss: 0.1776
# Epoch: 008/050 | Batch 0150/0210 | Loss: 0.1499
# Epoch: 008/050 | Batch 0200/0210 | Loss: 0.3386
# Epoch: 008/050 | Train: 95.34% | Validation: 95.93%
# Time elapsed: 0.44 min
# Epoch: 009/050 | Batch 0000/0210 | Loss: 0.1533
# Epoch: 009/050 | Batch 0050/0210 | Loss: 0.1181
# Epoch: 009/050 | Batch 0100/0210 | Loss: 0.1694
# Epoch: 009/050 | Batch 0150/0210 | Loss: 0.1293
# Epoch: 009/050 | Batch 0200/0210 | Loss: 0.1594
# Epoch: 009/050 | Train: 95.94% | Validation: 96.68%
# Time elapsed: 0.50 min
# Epoch: 010/050 | Batch 0000/0210 | Loss: 0.1791
# Epoch: 010/050 | Batch 0050/0210 | Loss: 0.1264
# Epoch: 010/050 | Batch 0100/0210 | Loss: 0.1002
# Epoch: 010/050 | Batch 0150/0210 | Loss: 0.1371
# Epoch: 010/050 | Batch 0200/0210 | Loss: 0.1368
# Epoch: 010/050 | Train: 96.17% | Validation: 96.45%
# Time elapsed: 0.55 min
# Epoch: 011/050 | Batch 0000/0210 | Loss: 0.1382
# Epoch: 011/050 | Batch 0050/0210 | Loss: 0.1420
# Epoch: 011/050 | Batch 0100/0210 | Loss: 0.1088
# Epoch: 011/050 | Batch 0150/0210 | Loss: 0.1898
# Epoch: 011/050 | Batch 0200/0210 | Loss: 0.1513
# Epoch: 011/050 | Train: 96.62% | Validation: 96.93%
# Time elapsed: 0.61 min
# Epoch: 012/050 | Batch 0000/0210 | Loss: 0.1353
# Epoch: 012/050 | Batch 0050/0210 | Loss: 0.1532
# Epoch: 012/050 | Batch 0100/0210 | Loss: 0.0984
# Epoch: 012/050 | Batch 0150/0210 | Loss: 0.1301
# Epoch: 012/050 | Batch 0200/0210 | Loss: 0.1254
# Epoch: 012/050 | Train: 96.79% | Validation: 96.97%
# Time elapsed: 0.66 min
# Epoch: 013/050 | Batch 0000/0210 | Loss: 0.0998
# Epoch: 013/050 | Batch 0050/0210 | Loss: 0.2296
# Epoch: 013/050 | Batch 0100/0210 | Loss: 0.1359
# Epoch: 013/050 | Batch 0150/0210 | Loss: 0.1056
# Epoch: 013/050 | Batch 0200/0210 | Loss: 0.0947
# Epoch: 013/050 | Train: 97.01% | Validation: 97.15%
# Time elapsed: 0.72 min
# Epoch: 014/050 | Batch 0000/0210 | Loss: 0.0894
# Epoch: 014/050 | Batch 0050/0210 | Loss: 0.1462
# Epoch: 014/050 | Batch 0100/0210 | Loss: 0.1106
# Epoch: 014/050 | Batch 0150/0210 | Loss: 0.1051
# Epoch: 014/050 | Batch 0200/0210 | Loss: 0.0833
# Epoch: 014/050 | Train: 97.33% | Validation: 97.30%
# Time elapsed: 0.78 min
# Epoch: 015/050 | Batch 0000/0210 | Loss: 0.0827
# Epoch: 015/050 | Batch 0050/0210 | Loss: 0.0500
# Epoch: 015/050 | Batch 0100/0210 | Loss: 0.0843
# Epoch: 015/050 | Batch 0150/0210 | Loss: 0.0961
# Epoch: 015/050 | Batch 0200/0210 | Loss: 0.0765
# Epoch: 015/050 | Train: 97.21% | Validation: 96.95%
# Time elapsed: 0.84 min
# Epoch: 016/050 | Batch 0000/0210 | Loss: 0.0574
# Epoch: 016/050 | Batch 0050/0210 | Loss: 0.0620
# Epoch: 016/050 | Batch 0100/0210 | Loss: 0.0673
# Epoch: 016/050 | Batch 0150/0210 | Loss: 0.1027
# Epoch: 016/050 | Batch 0200/0210 | Loss: 0.0714
# Epoch: 016/050 | Train: 97.62% | Validation: 97.32%
# Time elapsed: 0.89 min
# Epoch: 017/050 | Batch 0000/0210 | Loss: 0.0821
# Epoch: 017/050 | Batch 0050/0210 | Loss: 0.0707
# Epoch: 017/050 | Batch 0100/0210 | Loss: 0.1281
# Epoch: 017/050 | Batch 0150/0210 | Loss: 0.0421
# Epoch: 017/050 | Batch 0200/0210 | Loss: 0.0922
# Epoch: 017/050 | Train: 97.80% | Validation: 97.48%
# Time elapsed: 0.95 min
# Epoch: 018/050 | Batch 0000/0210 | Loss: 0.0953
# Epoch: 018/050 | Batch 0050/0210 | Loss: 0.0764
# Epoch: 018/050 | Batch 0100/0210 | Loss: 0.0693
# Epoch: 018/050 | Batch 0150/0210 | Loss: 0.1096
# Epoch: 018/050 | Batch 0200/0210 | Loss: 0.0804
# Epoch: 018/050 | Train: 97.85% | Validation: 97.48%
# Time elapsed: 1.01 min
# Epoch: 019/050 | Batch 0000/0210 | Loss: 0.0575
# Epoch: 019/050 | Batch 0050/0210 | Loss: 0.0452
# Epoch: 019/050 | Batch 0100/0210 | Loss: 0.0400
# Epoch: 019/050 | Batch 0150/0210 | Loss: 0.0705
# Epoch: 019/050 | Batch 0200/0210 | Loss: 0.1273
# Epoch: 019/050 | Train: 97.89% | Validation: 97.43%
# Time elapsed: 1.07 min
# Epoch: 020/050 | Batch 0000/0210 | Loss: 0.0946
# Epoch: 020/050 | Batch 0050/0210 | Loss: 0.0869
# Epoch: 020/050 | Batch 0100/0210 | Loss: 0.0691
# Epoch: 020/050 | Batch 0150/0210 | Loss: 0.0936
# Epoch: 020/050 | Batch 0200/0210 | Loss: 0.0915
# Epoch: 020/050 | Train: 98.16% | Validation: 97.55%
# Time elapsed: 1.12 min
# Epoch: 021/050 | Batch 0000/0210 | Loss: 0.0815
# Epoch: 021/050 | Batch 0050/0210 | Loss: 0.0382
# Epoch: 021/050 | Batch 0100/0210 | Loss: 0.0610
# Epoch: 021/050 | Batch 0150/0210 | Loss: 0.0654
# Epoch: 021/050 | Batch 0200/0210 | Loss: 0.0930
# Epoch: 021/050 | Train: 98.22% | Validation: 97.50%
# Time elapsed: 1.18 min
# Epoch: 022/050 | Batch 0000/0210 | Loss: 0.0350
# Epoch: 022/050 | Batch 0050/0210 | Loss: 0.0777
# Epoch: 022/050 | Batch 0100/0210 | Loss: 0.0734
# Epoch: 022/050 | Batch 0150/0210 | Loss: 0.0787
# Epoch: 022/050 | Batch 0200/0210 | Loss: 0.0355
# Epoch: 022/050 | Train: 98.35% | Validation: 97.42%
# Time elapsed: 1.24 min
# Epoch: 023/050 | Batch 0000/0210 | Loss: 0.0235
# Epoch: 023/050 | Batch 0050/0210 | Loss: 0.0601
# Epoch: 023/050 | Batch 0100/0210 | Loss: 0.0488
# Epoch: 023/050 | Batch 0150/0210 | Loss: 0.0690
# Epoch: 023/050 | Batch 0200/0210 | Loss: 0.0432
# Epoch: 023/050 | Train: 98.43% | Validation: 97.63%
# Time elapsed: 1.29 min
# Epoch: 024/050 | Batch 0000/0210 | Loss: 0.0465
# Epoch: 024/050 | Batch 0050/0210 | Loss: 0.0583
# Epoch: 024/050 | Batch 0100/0210 | Loss: 0.0926
# Epoch: 024/050 | Batch 0150/0210 | Loss: 0.0565
# Epoch: 024/050 | Batch 0200/0210 | Loss: 0.0742
# Epoch: 024/050 | Train: 98.58% | Validation: 97.63%
# Time elapsed: 1.35 min
# Epoch: 025/050 | Batch 0000/0210 | Loss: 0.0494
# Epoch: 025/050 | Batch 0050/0210 | Loss: 0.0323
# Epoch: 025/050 | Batch 0100/0210 | Loss: 0.0440
# Epoch: 025/050 | Batch 0150/0210 | Loss: 0.0681
# Epoch: 025/050 | Batch 0200/0210 | Loss: 0.0548
# Epoch: 025/050 | Train: 98.59% | Validation: 97.55%
# Time elapsed: 1.40 min
# Epoch: 026/050 | Batch 0000/0210 | Loss: 0.0405
# Epoch: 026/050 | Batch 0050/0210 | Loss: 0.0454
# Epoch: 026/050 | Batch 0100/0210 | Loss: 0.0765
# Epoch: 026/050 | Batch 0150/0210 | Loss: 0.0363
# Epoch: 026/050 | Batch 0200/0210 | Loss: 0.0635
# Epoch: 026/050 | Train: 98.75% | Validation: 97.65%
# Time elapsed: 1.46 min
# Epoch: 027/050 | Batch 0000/0210 | Loss: 0.0546
# Epoch: 027/050 | Batch 0050/0210 | Loss: 0.0523
# Epoch: 027/050 | Batch 0100/0210 | Loss: 0.0416
# Epoch: 027/050 | Batch 0150/0210 | Loss: 0.0334
# Epoch: 027/050 | Batch 0200/0210 | Loss: 0.0946
# Epoch: 027/050 | Train: 98.79% | Validation: 97.67%
# Time elapsed: 1.51 min
# Epoch: 028/050 | Batch 0000/0210 | Loss: 0.0403
# Epoch: 028/050 | Batch 0050/0210 | Loss: 0.0693
# Epoch: 028/050 | Batch 0100/0210 | Loss: 0.0535
# Epoch: 028/050 | Batch 0150/0210 | Loss: 0.0411
# Epoch: 028/050 | Batch 0200/0210 | Loss: 0.0270
# Epoch: 028/050 | Train: 98.87% | Validation: 97.62%
# Time elapsed: 1.57 min
# Epoch: 029/050 | Batch 0000/0210 | Loss: 0.0514
# Epoch: 029/050 | Batch 0050/0210 | Loss: 0.0459
# Epoch: 029/050 | Batch 0100/0210 | Loss: 0.0497
# Epoch: 029/050 | Batch 0150/0210 | Loss: 0.0223
# Epoch: 029/050 | Batch 0200/0210 | Loss: 0.0452
# Epoch: 029/050 | Train: 98.92% | Validation: 97.80%
# Time elapsed: 1.63 min
# Epoch: 030/050 | Batch 0000/0210 | Loss: 0.0309
# Epoch: 030/050 | Batch 0050/0210 | Loss: 0.0274
# Epoch: 030/050 | Batch 0100/0210 | Loss: 0.0469
# Epoch: 030/050 | Batch 0150/0210 | Loss: 0.0290
# Epoch: 030/050 | Batch 0200/0210 | Loss: 0.0709
# Epoch: 030/050 | Train: 99.03% | Validation: 97.75%
# Time elapsed: 1.68 min
# Epoch: 031/050 | Batch 0000/0210 | Loss: 0.0277
# Epoch: 031/050 | Batch 0050/0210 | Loss: 0.0250
# Epoch: 031/050 | Batch 0100/0210 | Loss: 0.0310
# Epoch: 031/050 | Batch 0150/0210 | Loss: 0.0306
# Epoch: 031/050 | Batch 0200/0210 | Loss: 0.0371
# Epoch: 031/050 | Train: 98.70% | Validation: 97.42%
# Time elapsed: 1.74 min
# Epoch: 032/050 | Batch 0000/0210 | Loss: 0.0309
# Epoch: 032/050 | Batch 0050/0210 | Loss: 0.0759
# Epoch: 032/050 | Batch 0100/0210 | Loss: 0.0425
# Epoch: 032/050 | Batch 0150/0210 | Loss: 0.0446
# Epoch: 032/050 | Batch 0200/0210 | Loss: 0.0261
# Epoch: 032/050 | Train: 98.28% | Validation: 96.97%
# Time elapsed: 1.79 min
# Epoch: 033/050 | Batch 0000/0210 | Loss: 0.0475
# Epoch: 033/050 | Batch 0050/0210 | Loss: 0.0305
# Epoch: 033/050 | Batch 0100/0210 | Loss: 0.0241
# Epoch: 033/050 | Batch 0150/0210 | Loss: 0.0323
# Epoch: 033/050 | Batch 0200/0210 | Loss: 0.0371
# Epoch: 033/050 | Train: 99.15% | Validation: 97.62%
# Time elapsed: 1.85 min
# Epoch: 034/050 | Batch 0000/0210 | Loss: 0.0245
# Epoch: 034/050 | Batch 0050/0210 | Loss: 0.0607
# Epoch: 034/050 | Batch 0100/0210 | Loss: 0.0354
# Epoch: 034/050 | Batch 0150/0210 | Loss: 0.0387
# Epoch: 034/050 | Batch 0200/0210 | Loss: 0.0306
# Epoch: 034/050 | Train: 99.09% | Validation: 97.70%
# Time elapsed: 1.91 min
# Epoch: 035/050 | Batch 0000/0210 | Loss: 0.0217
# Epoch: 035/050 | Batch 0050/0210 | Loss: 0.0373
# Epoch: 035/050 | Batch 0100/0210 | Loss: 0.0236
# Epoch: 035/050 | Batch 0150/0210 | Loss: 0.0244
# Epoch: 035/050 | Batch 0200/0210 | Loss: 0.0366
# Epoch: 035/050 | Train: 99.22% | Validation: 97.78%
# Time elapsed: 1.96 min
# Epoch: 036/050 | Batch 0000/0210 | Loss: 0.0637
# Epoch: 036/050 | Batch 0050/0210 | Loss: 0.0111
# Epoch: 036/050 | Batch 0100/0210 | Loss: 0.0399
# Epoch: 036/050 | Batch 0150/0210 | Loss: 0.0378
# Epoch: 036/050 | Batch 0200/0210 | Loss: 0.0248
# Epoch: 036/050 | Train: 99.27% | Validation: 97.67%
# Time elapsed: 2.02 min
# Epoch: 037/050 | Batch 0000/0210 | Loss: 0.0358
# Epoch: 037/050 | Batch 0050/0210 | Loss: 0.0206
# Epoch: 037/050 | Batch 0100/0210 | Loss: 0.0528
# Epoch: 037/050 | Batch 0150/0210 | Loss: 0.0118
# Epoch: 037/050 | Batch 0200/0210 | Loss: 0.0302
# Epoch: 037/050 | Train: 99.32% | Validation: 97.83%
# Time elapsed: 2.07 min
# Epoch: 038/050 | Batch 0000/0210 | Loss: 0.0256
# Epoch: 038/050 | Batch 0050/0210 | Loss: 0.0468
# Epoch: 038/050 | Batch 0100/0210 | Loss: 0.0311
# Epoch: 038/050 | Batch 0150/0210 | Loss: 0.0568
# Epoch: 038/050 | Batch 0200/0210 | Loss: 0.0178
# Epoch: 038/050 | Train: 99.15% | Validation: 97.75%
# Time elapsed: 2.13 min
# Epoch: 039/050 | Batch 0000/0210 | Loss: 0.0142
# Epoch: 039/050 | Batch 0050/0210 | Loss: 0.0261
# Epoch: 039/050 | Batch 0100/0210 | Loss: 0.0415
# Epoch: 039/050 | Batch 0150/0210 | Loss: 0.0950
# Epoch: 039/050 | Batch 0200/0210 | Loss: 0.0267
# Epoch: 039/050 | Train: 99.33% | Validation: 97.77%
# Time elapsed: 2.18 min
# Epoch: 040/050 | Batch 0000/0210 | Loss: 0.0146
# Epoch: 040/050 | Batch 0050/0210 | Loss: 0.0452
# Epoch: 040/050 | Batch 0100/0210 | Loss: 0.0201
# Epoch: 040/050 | Batch 0150/0210 | Loss: 0.0207
# Epoch: 040/050 | Batch 0200/0210 | Loss: 0.0295
# Epoch: 040/050 | Train: 99.34% | Validation: 97.78%
# Time elapsed: 2.23 min
# Epoch: 041/050 | Batch 0000/0210 | Loss: 0.0452
# Epoch: 041/050 | Batch 0050/0210 | Loss: 0.0298
# Epoch: 041/050 | Batch 0100/0210 | Loss: 0.0237
# Epoch: 041/050 | Batch 0150/0210 | Loss: 0.0251
# Epoch: 041/050 | Batch 0200/0210 | Loss: 0.0215
# Epoch: 041/050 | Train: 99.54% | Validation: 97.90%
# Time elapsed: 2.29 min
# Epoch: 042/050 | Batch 0000/0210 | Loss: 0.0098
# Epoch: 042/050 | Batch 0050/0210 | Loss: 0.0247
# Epoch: 042/050 | Batch 0100/0210 | Loss: 0.0530
# Epoch: 042/050 | Batch 0150/0210 | Loss: 0.0422
# Epoch: 042/050 | Batch 0200/0210 | Loss: 0.0273
# Epoch: 042/050 | Train: 99.50% | Validation: 97.77%
# Time elapsed: 2.35 min
# Epoch: 043/050 | Batch 0000/0210 | Loss: 0.0199
# Epoch: 043/050 | Batch 0050/0210 | Loss: 0.0219
# Epoch: 043/050 | Batch 0100/0210 | Loss: 0.0191
# Epoch: 043/050 | Batch 0150/0210 | Loss: 0.0192
# Epoch: 043/050 | Batch 0200/0210 | Loss: 0.0335
# Epoch: 043/050 | Train: 99.56% | Validation: 97.87%
# Time elapsed: 2.40 min
# Epoch: 044/050 | Batch 0000/0210 | Loss: 0.0173
# Epoch: 044/050 | Batch 0050/0210 | Loss: 0.0149
# Epoch: 044/050 | Batch 0100/0210 | Loss: 0.0217
# Epoch: 044/050 | Batch 0150/0210 | Loss: 0.0251
# Epoch: 044/050 | Batch 0200/0210 | Loss: 0.0111
# Epoch: 044/050 | Train: 99.62% | Validation: 97.85%
# Time elapsed: 2.45 min
# Epoch: 045/050 | Batch 0000/0210 | Loss: 0.0152
# Epoch: 045/050 | Batch 0050/0210 | Loss: 0.0175
# Epoch: 045/050 | Batch 0100/0210 | Loss: 0.0141
# Epoch: 045/050 | Batch 0150/0210 | Loss: 0.0144
# Epoch: 045/050 | Batch 0200/0210 | Loss: 0.0106
# Epoch: 045/050 | Train: 99.55% | Validation: 97.78%
# Time elapsed: 2.51 min
# Epoch: 046/050 | Batch 0000/0210 | Loss: 0.0378
# Epoch: 046/050 | Batch 0050/0210 | Loss: 0.0365
# Epoch: 046/050 | Batch 0100/0210 | Loss: 0.0118
# Epoch: 046/050 | Batch 0150/0210 | Loss: 0.0188
# Epoch: 046/050 | Batch 0200/0210 | Loss: 0.0224
# Epoch: 046/050 | Train: 99.36% | Validation: 97.60%
# Time elapsed: 2.56 min
# Epoch: 047/050 | Batch 0000/0210 | Loss: 0.0299
# Epoch: 047/050 | Batch 0050/0210 | Loss: 0.0072
# Epoch: 047/050 | Batch 0100/0210 | Loss: 0.0279
# Epoch: 047/050 | Batch 0150/0210 | Loss: 0.0164
# Epoch: 047/050 | Batch 0200/0210 | Loss: 0.0118
# Epoch: 047/050 | Train: 99.64% | Validation: 97.90%
# Time elapsed: 2.61 min
# Epoch: 048/050 | Batch 0000/0210 | Loss: 0.0549
# Epoch: 048/050 | Batch 0050/0210 | Loss: 0.0110
# Epoch: 048/050 | Batch 0100/0210 | Loss: 0.0103
# Epoch: 048/050 | Batch 0150/0210 | Loss: 0.0295
# Epoch: 048/050 | Batch 0200/0210 | Loss: 0.0248
# Epoch: 048/050 | Train: 99.57% | Validation: 97.78%
# Time elapsed: 2.67 min
# Epoch: 049/050 | Batch 0000/0210 | Loss: 0.0173
# Epoch: 049/050 | Batch 0050/0210 | Loss: 0.0174
# Epoch: 049/050 | Batch 0100/0210 | Loss: 0.0192
# Epoch: 049/050 | Batch 0150/0210 | Loss: 0.0149
# Epoch: 049/050 | Batch 0200/0210 | Loss: 0.0113
# Epoch: 049/050 | Train: 99.68% | Validation: 97.80%
# Time elapsed: 2.72 min
# Epoch: 050/050 | Batch 0000/0210 | Loss: 0.0160
# Epoch: 050/050 | Batch 0050/0210 | Loss: 0.0184
# Epoch: 050/050 | Batch 0100/0210 | Loss: 0.0184
# Epoch: 050/050 | Batch 0150/0210 | Loss: 0.0189
# Epoch: 050/050 | Batch 0200/0210 | Loss: 0.0153
# Epoch: 050/050 | Train: 99.74% | Validation: 97.82%
# Time elapsed: 2.79 min
# Total Training Time: 2.79 min
# Test accuracy 97.73%
