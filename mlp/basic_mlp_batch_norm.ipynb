# %% [markdown]
# # Basic Multilayer Perceptron - Batch Norm

# %% [markdown]
# This notebook has the same MLP as the basic MLP notebook, but now add a normalization function before the activation function in the hidden layers.
#
# I will use batch norm as my normalization function

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# From local helper files
from mlp.helpers.helper_datasets import get_dataloaders_mnist
from mlp.helpers.helper_train import train_model
from mlp.helpers.helper_plotting import plot_training_loss, plot_accuracy

# %% [markdown]
# # Settings and Dataset

# %%
##########################
### SETTINGS
##########################

RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_HIDDEN_1 = 75
NUM_HIDDEN_2 = 45
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Get Data
train_loader, valid_loader, test_loader = get_dataloaders_mnist(
    batch_size=BATCH_SIZE,
    validation_fraction=0.1)

# %% [markdown]
# # Model
# We will create a basic multilayer perceptron neural network using pytorch.
#
# The network will have 784 input features corresponding to the 28*28 MNIST images
#
# The network will predict that the image is one of ten classes corresponding to numbers from 0 to 9
#
# The network will have 2 hidden layers, see NUM_HIDDEN_1 and NUM_HIDDEN_2 for their sizes

# %%
class MLP(torch.nn.Module):
    def __init__(self, num_features, num_classes, drop_proba, num_hidden_1, num_hidden_2):
        super().__init__()
        self.network = torch.nn.Sequential(
            # Layer 1
            torch.nn.Flatten(),
            torch.nn.Linear(num_features, num_hidden_1),
            torch.nn.BatchNorm1d(num_hidden_1),
            torch.nn.ReLU(),
            # Layer 2
            torch.nn.Linear(num_hidden_1, num_hidden_2),
            torch.nn.BatchNorm1d(num_hidden_2),
            torch.nn.ReLU(),
            # Output layer
            torch.nn.Linear(num_hidden_2, num_classes)
        )
    
    def forward(self, x):
        return self.network(x)

# %%
torch.manual_seed(RANDOM_SEED)

model = MLP(num_features=28*28,
            num_classes=10,
            num_hidden_1=NUM_HIDDEN_1,
            num_hidden_2=NUM_HIDDEN_2,
            drop_proba=0.5)


optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(model=model, 
                                                                  num_epochs=NUM_EPOCHS, 
                                                                  train_loader=train_loader,
                                                                  valid_loader=valid_loader, 
                                                                  test_loader=test_loader, 
                                                                  optimizer=optimizer,
                                                                  device=DEVICE)


plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=20)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([80, 100])
plt.show()
# Out:
# Epoch: 001/050 | Batch 0000/0210 | Loss: 2.3118
# Epoch: 001/050 | Batch 0050/0210 | Loss: 0.4538
# Epoch: 001/050 | Batch 0100/0210 | Loss: 0.2231
# Epoch: 001/050 | Batch 0150/0210 | Loss: 0.2531
# Epoch: 001/050 | Batch 0200/0210 | Loss: 0.1575
# Epoch: 001/050 | Train: 95.47% | Validation: 96.07%
# Time elapsed: 0.06 min
# Epoch: 002/050 | Batch 0000/0210 | Loss: 0.1335
# Epoch: 002/050 | Batch 0050/0210 | Loss: 0.1476
# Epoch: 002/050 | Batch 0100/0210 | Loss: 0.1519
# Epoch: 002/050 | Batch 0150/0210 | Loss: 0.1360
# Epoch: 002/050 | Batch 0200/0210 | Loss: 0.1608
# Epoch: 002/050 | Train: 97.20% | Validation: 97.12%
# Time elapsed: 0.12 min
# Epoch: 003/050 | Batch 0000/0210 | Loss: 0.0812
# Epoch: 003/050 | Batch 0050/0210 | Loss: 0.0909
# Epoch: 003/050 | Batch 0100/0210 | Loss: 0.0825
# Epoch: 003/050 | Batch 0150/0210 | Loss: 0.0477
# Epoch: 003/050 | Batch 0200/0210 | Loss: 0.1271
# Epoch: 003/050 | Train: 97.96% | Validation: 97.48%
# Time elapsed: 0.17 min
# Epoch: 004/050 | Batch 0000/0210 | Loss: 0.0625
# Epoch: 004/050 | Batch 0050/0210 | Loss: 0.0990
# Epoch: 004/050 | Batch 0100/0210 | Loss: 0.0834
# Epoch: 004/050 | Batch 0150/0210 | Loss: 0.1345
# Epoch: 004/050 | Batch 0200/0210 | Loss: 0.0972
# Epoch: 004/050 | Train: 98.44% | Validation: 97.45%
# Time elapsed: 0.23 min
# Epoch: 005/050 | Batch 0000/0210 | Loss: 0.0635
# Epoch: 005/050 | Batch 0050/0210 | Loss: 0.0356
# Epoch: 005/050 | Batch 0100/0210 | Loss: 0.0371
# Epoch: 005/050 | Batch 0150/0210 | Loss: 0.0461
# Epoch: 005/050 | Batch 0200/0210 | Loss: 0.0598
# Epoch: 005/050 | Train: 98.66% | Validation: 97.57%
# Time elapsed: 0.29 min
# Epoch: 006/050 | Batch 0000/0210 | Loss: 0.0469
# Epoch: 006/050 | Batch 0050/0210 | Loss: 0.0457
# Epoch: 006/050 | Batch 0100/0210 | Loss: 0.0497
# Epoch: 006/050 | Batch 0150/0210 | Loss: 0.0281
# Epoch: 006/050 | Batch 0200/0210 | Loss: 0.0822
# Epoch: 006/050 | Train: 99.15% | Validation: 98.00%
# Time elapsed: 0.34 min
# Epoch: 007/050 | Batch 0000/0210 | Loss: 0.0390
# Epoch: 007/050 | Batch 0050/0210 | Loss: 0.0480
# Epoch: 007/050 | Batch 0100/0210 | Loss: 0.0326
# Epoch: 007/050 | Batch 0150/0210 | Loss: 0.0464
# Epoch: 007/050 | Batch 0200/0210 | Loss: 0.0305
# Epoch: 007/050 | Train: 99.22% | Validation: 97.78%
# Time elapsed: 0.40 min
# Epoch: 008/050 | Batch 0000/0210 | Loss: 0.0477
# Epoch: 008/050 | Batch 0050/0210 | Loss: 0.0472
# Epoch: 008/050 | Batch 0100/0210 | Loss: 0.0459
# Epoch: 008/050 | Batch 0150/0210 | Loss: 0.0292
# Epoch: 008/050 | Batch 0200/0210 | Loss: 0.1195
# Epoch: 008/050 | Train: 98.99% | Validation: 97.53%
# Time elapsed: 0.45 min
# Epoch: 009/050 | Batch 0000/0210 | Loss: 0.0263
# Epoch: 009/050 | Batch 0050/0210 | Loss: 0.0329
# Epoch: 009/050 | Batch 0100/0210 | Loss: 0.0454
# Epoch: 009/050 | Batch 0150/0210 | Loss: 0.0311
# Epoch: 009/050 | Batch 0200/0210 | Loss: 0.0380
# Epoch: 009/050 | Train: 99.56% | Validation: 97.95%
# Time elapsed: 0.51 min
# Epoch: 010/050 | Batch 0000/0210 | Loss: 0.0350
# Epoch: 010/050 | Batch 0050/0210 | Loss: 0.0220
# Epoch: 010/050 | Batch 0100/0210 | Loss: 0.0135
# Epoch: 010/050 | Batch 0150/0210 | Loss: 0.0172
# Epoch: 010/050 | Batch 0200/0210 | Loss: 0.0207
# Epoch: 010/050 | Train: 99.52% | Validation: 98.03%
# Time elapsed: 0.57 min
# Epoch: 011/050 | Batch 0000/0210 | Loss: 0.0335
# Epoch: 011/050 | Batch 0050/0210 | Loss: 0.0244
# Epoch: 011/050 | Batch 0100/0210 | Loss: 0.0221
# Epoch: 011/050 | Batch 0150/0210 | Loss: 0.0396
# Epoch: 011/050 | Batch 0200/0210 | Loss: 0.0275
# Epoch: 011/050 | Train: 99.67% | Validation: 97.75%
# Time elapsed: 0.62 min
# Epoch: 012/050 | Batch 0000/0210 | Loss: 0.0133
# Epoch: 012/050 | Batch 0050/0210 | Loss: 0.0289
# Epoch: 012/050 | Batch 0100/0210 | Loss: 0.0217
# Epoch: 012/050 | Batch 0150/0210 | Loss: 0.0293
# Epoch: 012/050 | Batch 0200/0210 | Loss: 0.0163
# Epoch: 012/050 | Train: 99.70% | Validation: 97.95%
# Time elapsed: 0.68 min
# Epoch: 013/050 | Batch 0000/0210 | Loss: 0.0122
# Epoch: 013/050 | Batch 0050/0210 | Loss: 0.0349
# Epoch: 013/050 | Batch 0100/0210 | Loss: 0.0140
# Epoch: 013/050 | Batch 0150/0210 | Loss: 0.0168
# Epoch: 013/050 | Batch 0200/0210 | Loss: 0.0151
# Epoch: 013/050 | Train: 99.81% | Validation: 97.97%
# Time elapsed: 0.73 min
# Epoch: 014/050 | Batch 0000/0210 | Loss: 0.0109
# Epoch: 014/050 | Batch 0050/0210 | Loss: 0.0142
# Epoch: 014/050 | Batch 0100/0210 | Loss: 0.0219
# Epoch: 014/050 | Batch 0150/0210 | Loss: 0.0163
# Epoch: 014/050 | Batch 0200/0210 | Loss: 0.0199
# Epoch: 014/050 | Train: 99.77% | Validation: 97.82%
# Time elapsed: 0.79 min
# Epoch: 015/050 | Batch 0000/0210 | Loss: 0.0197
# Epoch: 015/050 | Batch 0050/0210 | Loss: 0.0043
# Epoch: 015/050 | Batch 0100/0210 | Loss: 0.0147
# Epoch: 015/050 | Batch 0150/0210 | Loss: 0.0106
# Epoch: 015/050 | Batch 0200/0210 | Loss: 0.0138
# Epoch: 016/050 | Batch 0100/0210 | Loss: 0.0079
# Epoch: 016/050 | Batch 0150/0210 | Loss: 0.0185
# Epoch: 016/050 | Batch 0200/0210 | Loss: 0.0132
# Epoch: 015/050 | Train: 99.48% | Validation: 97.50%
# Time elapsed: 0.85 min
# Epoch: 016/050 | Batch 0000/0210 | Loss: 0.0075
# Epoch: 016/050 | Batch 0050/0210 | Loss: 0.0101
# Epoch: 016/050 | Train: 99.85% | Validation: 97.98%
# Time elapsed: 0.91 min
# Epoch: 017/050 | Batch 0000/0210 | Loss: 0.0093
# Epoch: 017/050 | Batch 0050/0210 | Loss: 0.0087
# Epoch: 017/050 | Batch 0100/0210 | Loss: 0.0093
# Epoch: 017/050 | Batch 0150/0210 | Loss: 0.0117
# Epoch: 017/050 | Batch 0200/0210 | Loss: 0.0164
# Epoch: 017/050 | Train: 99.91% | Validation: 97.95%
# Time elapsed: 0.97 min
# Epoch: 018/050 | Batch 0000/0210 | Loss: 0.0077
# Epoch: 018/050 | Batch 0050/0210 | Loss: 0.0070
# Epoch: 018/050 | Batch 0100/0210 | Loss: 0.0110
# Epoch: 018/050 | Batch 0150/0210 | Loss: 0.0275
# Epoch: 018/050 | Batch 0200/0210 | Loss: 0.0078
# Epoch: 018/050 | Train: 99.96% | Validation: 98.13%
# Time elapsed: 1.03 min
# Epoch: 019/050 | Batch 0000/0210 | Loss: 0.0040
# Epoch: 019/050 | Batch 0050/0210 | Loss: 0.0058
# Epoch: 019/050 | Batch 0100/0210 | Loss: 0.0057
# Epoch: 019/050 | Batch 0150/0210 | Loss: 0.0048
# Epoch: 019/050 | Batch 0200/0210 | Loss: 0.0070
# Epoch: 019/050 | Train: 99.93% | Validation: 98.07%
# Time elapsed: 1.09 min
# Epoch: 020/050 | Batch 0000/0210 | Loss: 0.0099
# Epoch: 020/050 | Batch 0050/0210 | Loss: 0.0062
# Epoch: 020/050 | Batch 0100/0210 | Loss: 0.0183
# Epoch: 020/050 | Batch 0150/0210 | Loss: 0.0152
# Epoch: 020/050 | Batch 0200/0210 | Loss: 0.0063
# Epoch: 020/050 | Train: 99.95% | Validation: 98.02%
# Time elapsed: 1.14 min
# Epoch: 021/050 | Batch 0000/0210 | Loss: 0.0099
# Epoch: 021/050 | Batch 0050/0210 | Loss: 0.0036
# Epoch: 021/050 | Batch 0100/0210 | Loss: 0.0048
# Epoch: 021/050 | Batch 0150/0210 | Loss: 0.0059
# Epoch: 021/050 | Batch 0200/0210 | Loss: 0.0057
# Epoch: 021/050 | Train: 99.98% | Validation: 97.92%
# Time elapsed: 1.20 min
# Epoch: 022/050 | Batch 0000/0210 | Loss: 0.0029
# Epoch: 022/050 | Batch 0050/0210 | Loss: 0.0065
# Epoch: 022/050 | Batch 0100/0210 | Loss: 0.0152
# Epoch: 022/050 | Batch 0150/0210 | Loss: 0.0067
# Epoch: 022/050 | Batch 0200/0210 | Loss: 0.0053
# Epoch: 022/050 | Train: 99.99% | Validation: 98.03%
# Time elapsed: 1.26 min
# Epoch: 023/050 | Batch 0000/0210 | Loss: 0.0059
# Epoch: 023/050 | Batch 0050/0210 | Loss: 0.0068
# Epoch: 023/050 | Batch 0100/0210 | Loss: 0.0062
# Epoch: 023/050 | Batch 0150/0210 | Loss: 0.0034
# Epoch: 023/050 | Batch 0200/0210 | Loss: 0.0077
# Epoch: 023/050 | Train: 99.98% | Validation: 98.27%
# Time elapsed: 1.31 min
# Epoch: 024/050 | Batch 0000/0210 | Loss: 0.0062
# Epoch: 024/050 | Batch 0050/0210 | Loss: 0.0066
# Epoch: 024/050 | Batch 0100/0210 | Loss: 0.0077
# Epoch: 024/050 | Batch 0150/0210 | Loss: 0.0060
# Epoch: 024/050 | Batch 0200/0210 | Loss: 0.0078
# Epoch: 024/050 | Train: 99.98% | Validation: 98.15%
# Time elapsed: 1.36 min
# Epoch: 025/050 | Batch 0000/0210 | Loss: 0.0091
# Epoch: 025/050 | Batch 0050/0210 | Loss: 0.0022
# Epoch: 025/050 | Batch 0100/0210 | Loss: 0.0054
# Epoch: 025/050 | Batch 0150/0210 | Loss: 0.0097
# Epoch: 025/050 | Batch 0200/0210 | Loss: 0.0095
# Epoch: 025/050 | Train: 99.99% | Validation: 98.13%
# Time elapsed: 1.42 min
# Epoch: 026/050 | Batch 0000/0210 | Loss: 0.0039
# Epoch: 026/050 | Batch 0050/0210 | Loss: 0.0041
# Epoch: 026/050 | Batch 0100/0210 | Loss: 0.0066
# Epoch: 026/050 | Batch 0150/0210 | Loss: 0.0050
# Epoch: 026/050 | Batch 0200/0210 | Loss: 0.0050
# Epoch: 026/050 | Train: 99.97% | Validation: 98.05%
# Time elapsed: 1.48 min
# Epoch: 027/050 | Batch 0000/0210 | Loss: 0.0062
# Epoch: 027/050 | Batch 0050/0210 | Loss: 0.0039
# Epoch: 027/050 | Batch 0100/0210 | Loss: 0.0067
# Epoch: 027/050 | Batch 0150/0210 | Loss: 0.0049
# Epoch: 027/050 | Batch 0200/0210 | Loss: 0.0057
# Epoch: 027/050 | Train: 99.99% | Validation: 98.10%
# Time elapsed: 1.53 min
# Epoch: 028/050 | Batch 0000/0210 | Loss: 0.0039
# Epoch: 028/050 | Batch 0050/0210 | Loss: 0.0139
# Epoch: 028/050 | Batch 0100/0210 | Loss: 0.0051
# Epoch: 028/050 | Batch 0150/0210 | Loss: 0.0043
# Epoch: 028/050 | Batch 0200/0210 | Loss: 0.0042
# Epoch: 028/050 | Train: 100.00% | Validation: 98.13%
# Time elapsed: 1.59 min
# Epoch: 029/050 | Batch 0000/0210 | Loss: 0.0021
# Epoch: 029/050 | Batch 0050/0210 | Loss: 0.0045
# Epoch: 029/050 | Batch 0100/0210 | Loss: 0.0020
# Epoch: 029/050 | Batch 0150/0210 | Loss: 0.0021
# Epoch: 029/050 | Batch 0200/0210 | Loss: 0.0062
# Epoch: 029/050 | Train: 100.00% | Validation: 98.12%
# Time elapsed: 1.64 min
# Epoch: 030/050 | Batch 0000/0210 | Loss: 0.0031
# Epoch: 030/050 | Batch 0050/0210 | Loss: 0.0032
# Epoch: 030/050 | Batch 0100/0210 | Loss: 0.0035
# Epoch: 030/050 | Batch 0150/0210 | Loss: 0.0043
# Epoch: 030/050 | Batch 0200/0210 | Loss: 0.0105
# Epoch: 030/050 | Train: 100.00% | Validation: 98.18%
# Time elapsed: 1.70 min
# Epoch: 031/050 | Batch 0000/0210 | Loss: 0.0024
# Epoch: 031/050 | Batch 0050/0210 | Loss: 0.0025
# Epoch: 031/050 | Batch 0100/0210 | Loss: 0.0015
# Epoch: 031/050 | Batch 0150/0210 | Loss: 0.0018
# Epoch: 031/050 | Batch 0200/0210 | Loss: 0.0049
# Epoch: 031/050 | Train: 100.00% | Validation: 98.07%
# Time elapsed: 1.75 min
# Epoch: 032/050 | Batch 0000/0210 | Loss: 0.0062
# Epoch: 032/050 | Batch 0050/0210 | Loss: 0.0041
# Epoch: 032/050 | Batch 0100/0210 | Loss: 0.0055
# Epoch: 032/050 | Batch 0150/0210 | Loss: 0.0024
# Epoch: 032/050 | Batch 0200/0210 | Loss: 0.0028
# Epoch: 032/050 | Train: 100.00% | Validation: 98.20%
# Time elapsed: 1.81 min
# Epoch: 033/050 | Batch 0000/0210 | Loss: 0.0026
# Epoch: 033/050 | Batch 0050/0210 | Loss: 0.0022
# Epoch: 033/050 | Batch 0100/0210 | Loss: 0.0020
# Epoch: 033/050 | Batch 0150/0210 | Loss: 0.0034
# Epoch: 033/050 | Batch 0200/0210 | Loss: 0.0037
# Epoch: 033/050 | Train: 99.99% | Validation: 97.93%
# Time elapsed: 1.86 min
# Epoch: 034/050 | Batch 0000/0210 | Loss: 0.0017
# Epoch: 034/050 | Batch 0050/0210 | Loss: 0.0081
# Epoch: 034/050 | Batch 0100/0210 | Loss: 0.0024
# Epoch: 034/050 | Batch 0150/0210 | Loss: 0.0018
# Epoch: 034/050 | Batch 0200/0210 | Loss: 0.0022
# Epoch: 034/050 | Train: 100.00% | Validation: 98.13%
# Time elapsed: 1.92 min
# Epoch: 035/050 | Batch 0000/0210 | Loss: 0.0021
# Epoch: 035/050 | Batch 0050/0210 | Loss: 0.0051
# Epoch: 035/050 | Batch 0100/0210 | Loss: 0.0019
# Epoch: 035/050 | Batch 0150/0210 | Loss: 0.0029
# Epoch: 035/050 | Batch 0200/0210 | Loss: 0.0041
# Epoch: 035/050 | Train: 100.00% | Validation: 98.22%
# Time elapsed: 1.98 min
# Epoch: 036/050 | Batch 0000/0210 | Loss: 0.0024
# Epoch: 036/050 | Batch 0050/0210 | Loss: 0.0009
# Epoch: 036/050 | Batch 0100/0210 | Loss: 0.0023
# Epoch: 036/050 | Batch 0150/0210 | Loss: 0.0018
# Epoch: 036/050 | Batch 0200/0210 | Loss: 0.0024
# Epoch: 036/050 | Train: 100.00% | Validation: 98.25%
# Time elapsed: 2.04 min
# Epoch: 037/050 | Batch 0000/0210 | Loss: 0.0011
# Epoch: 037/050 | Batch 0050/0210 | Loss: 0.0014
# Epoch: 037/050 | Batch 0100/0210 | Loss: 0.0036
# Epoch: 037/050 | Batch 0150/0210 | Loss: 0.0022
# Epoch: 037/050 | Batch 0200/0210 | Loss: 0.0018
# Epoch: 037/050 | Train: 100.00% | Validation: 98.05%
# Time elapsed: 2.10 min
# Epoch: 038/050 | Batch 0000/0210 | Loss: 0.0018
# Epoch: 038/050 | Batch 0050/0210 | Loss: 0.0018
# Epoch: 038/050 | Batch 0100/0210 | Loss: 0.0078
# Epoch: 038/050 | Batch 0150/0210 | Loss: 0.0033
# Epoch: 038/050 | Batch 0200/0210 | Loss: 0.0014
# Epoch: 038/050 | Train: 100.00% | Validation: 98.18%
# Time elapsed: 2.16 min
# Epoch: 039/050 | Batch 0000/0210 | Loss: 0.0034
# Epoch: 039/050 | Batch 0050/0210 | Loss: 0.0047
# Epoch: 039/050 | Batch 0100/0210 | Loss: 0.0016
# Epoch: 039/050 | Batch 0150/0210 | Loss: 0.0025
# Epoch: 039/050 | Batch 0200/0210 | Loss: 0.0016
# Epoch: 039/050 | Train: 99.99% | Validation: 98.17%
# Time elapsed: 2.22 min
# Epoch: 040/050 | Batch 0000/0210 | Loss: 0.0019
# Epoch: 040/050 | Batch 0050/0210 | Loss: 0.0020
# Epoch: 040/050 | Batch 0100/0210 | Loss: 0.0015
# Epoch: 040/050 | Batch 0150/0210 | Loss: 0.0017
# Epoch: 040/050 | Batch 0200/0210 | Loss: 0.0024
# Epoch: 040/050 | Train: 100.00% | Validation: 98.22%
# Time elapsed: 2.27 min
# Epoch: 041/050 | Batch 0000/0210 | Loss: 0.0042
# Epoch: 041/050 | Batch 0050/0210 | Loss: 0.0016
# Epoch: 041/050 | Batch 0100/0210 | Loss: 0.0031
# Epoch: 041/050 | Batch 0150/0210 | Loss: 0.0021
# Epoch: 041/050 | Batch 0200/0210 | Loss: 0.0021
# Epoch: 041/050 | Train: 100.00% | Validation: 98.25%
# Time elapsed: 2.33 min
# Epoch: 042/050 | Batch 0000/0210 | Loss: 0.0010
# Epoch: 042/050 | Batch 0050/0210 | Loss: 0.0062
# Epoch: 042/050 | Batch 0100/0210 | Loss: 0.0014
# Epoch: 042/050 | Batch 0150/0210 | Loss: 0.0043
# Epoch: 042/050 | Batch 0200/0210 | Loss: 0.0013
# Epoch: 042/050 | Train: 100.00% | Validation: 98.22%
# Time elapsed: 2.39 min
# Epoch: 043/050 | Batch 0000/0210 | Loss: 0.0015
# Epoch: 043/050 | Batch 0050/0210 | Loss: 0.0028
# Epoch: 043/050 | Batch 0100/0210 | Loss: 0.0016
# Epoch: 043/050 | Batch 0150/0210 | Loss: 0.0014
# Epoch: 043/050 | Batch 0200/0210 | Loss: 0.0018
# Epoch: 043/050 | Train: 100.00% | Validation: 98.15%
# Time elapsed: 2.45 min
# Epoch: 044/050 | Batch 0000/0210 | Loss: 0.0013
# Epoch: 044/050 | Batch 0050/0210 | Loss: 0.0017
# Epoch: 044/050 | Batch 0100/0210 | Loss: 0.0006
# Epoch: 044/050 | Batch 0150/0210 | Loss: 0.0020
# Epoch: 044/050 | Batch 0200/0210 | Loss: 0.0009
# Epoch: 044/050 | Train: 100.00% | Validation: 98.33%
# Time elapsed: 2.51 min
# Epoch: 045/050 | Batch 0000/0210 | Loss: 0.0023
# Epoch: 045/050 | Batch 0050/0210 | Loss: 0.0018
# Epoch: 045/050 | Batch 0100/0210 | Loss: 0.0021
# Epoch: 045/050 | Batch 0150/0210 | Loss: 0.0016
# Epoch: 045/050 | Batch 0200/0210 | Loss: 0.0017
# Epoch: 045/050 | Train: 100.00% | Validation: 98.20%
# Time elapsed: 2.56 min
# Epoch: 046/050 | Batch 0000/0210 | Loss: 0.0009
# Epoch: 046/050 | Batch 0050/0210 | Loss: 0.0038
# Epoch: 046/050 | Batch 0100/0210 | Loss: 0.0010
# Epoch: 046/050 | Batch 0150/0210 | Loss: 0.0018
# Epoch: 046/050 | Batch 0200/0210 | Loss: 0.0020
# Epoch: 046/050 | Train: 100.00% | Validation: 98.15%
# Time elapsed: 2.62 min
# Epoch: 047/050 | Batch 0000/0210 | Loss: 0.0019
# Epoch: 047/050 | Batch 0050/0210 | Loss: 0.0020
# Epoch: 047/050 | Batch 0100/0210 | Loss: 0.0014
# Epoch: 047/050 | Batch 0150/0210 | Loss: 0.0011
# Epoch: 047/050 | Batch 0200/0210 | Loss: 0.0013
# Epoch: 047/050 | Train: 100.00% | Validation: 98.27%
# Time elapsed: 2.68 min
# Epoch: 048/050 | Batch 0000/0210 | Loss: 0.0011
# Epoch: 048/050 | Batch 0050/0210 | Loss: 0.0015
# Epoch: 048/050 | Batch 0100/0210 | Loss: 0.0006
# Epoch: 048/050 | Batch 0150/0210 | Loss: 0.0018
# Epoch: 048/050 | Batch 0200/0210 | Loss: 0.0039
# Epoch: 048/050 | Train: 100.00% | Validation: 98.30%
# Time elapsed: 2.73 min
# Epoch: 049/050 | Batch 0000/0210 | Loss: 0.0012
# Epoch: 049/050 | Batch 0050/0210 | Loss: 0.0015
# Epoch: 049/050 | Batch 0100/0210 | Loss: 0.0013
# Epoch: 049/050 | Batch 0150/0210 | Loss: 0.0006
# Epoch: 049/050 | Batch 0200/0210 | Loss: 0.0015
# Epoch: 049/050 | Train: 100.00% | Validation: 98.30%
# Time elapsed: 2.79 min
# Epoch: 050/050 | Batch 0000/0210 | Loss: 0.0019
# Epoch: 050/050 | Batch 0050/0210 | Loss: 0.0018
# Epoch: 050/050 | Batch 0100/0210 | Loss: 0.0011
# Epoch: 050/050 | Batch 0150/0210 | Loss: 0.0019
# Epoch: 050/050 | Batch 0200/0210 | Loss: 0.0043
# Epoch: 050/050 | Train: 100.00% | Validation: 98.13%
# Time elapsed: 2.85 min
# Total Training Time: 2.85 min
# Test accuracy 97.86%
